# %%
from trainer.myGym.gymTrainer import gymSAC, gymDDPG
import matplotlib.pyplot as plt
gs = gymSAC('Pendulum-v1', render_mode=None)
gd = gymDDPG('Pendulum-v1', render_mode=None)

# %%
tr, cl, al, apl = gs.train(1, 100)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
plt.plot(tr)
plt.show()

# %%
tr, cl ,al = gd.train(1, 100)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from trainer.myGym.gymTrainer import gymSAC, gymDDPG
gs = gymSAC("Hopper-v4", max_episode_step=1200)

# %%
res = gs.train(1, 200)

# %%
import matplotlib.pyplot as plt
plt.plot(res[0])
plt.show()

# %%
from trainer.myGym.gymTrainer import gymPPO
import matplotlib.pyplot as plt
gp = gymPPO('Pendulum-v1', render_mode=None, actor_hiddens=[128]*2, critic_hiddens=[128]*2)
gp.agent.gamma = 0.9
gp.agent.lmd = 0.9

# %%
tr, cl, al = gp.train(1, 500)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
plt.plot(tr)
plt.show()

# %%
td = gp.simulate()
plt.plot(td["actions"])
plt.show()

# %%
from trainer.myGym.gymTrainer import gymPPO_discrete
import matplotlib.pyplot as plt
gp = gymPPO_discrete('CartPole-v1', render_mode=None)
gp.agent.gamma = 0.95

# %%
tr, cl, al = gp.train(1, 200)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
plt.plot(cl)
plt.show()
